# %%
import pdfplumber

file_path = 'dhaval.pdf'

# %%
with pdfplumber.open(file_path) as pdf:
  
    for page in pdf.pages:
        tables = page.extract_tables()
        t = 1
        
        for table in tables:
            print("\n")
            print("Table", table)
# Out:
# Table [['Member Information', None, None], ['JACKSON BENNETT 3/6/2013', None, None], ['Member ID: 5396419-02', 'Plan/Group #: CLAW010001', 'Eff. Date: 12/1/2021'], ['Benefit Plan: D03310', 'Plan Type: Passive MAC Plan', 'Term Date: Active']]
#
#
# Table [['In Network', None, None], ['Benefit Maximum - Annual', 'Individual', 'Family'], ['Orthodontics', '$0.00 used of $1,000.00\n$1,000.00 remains', 'N/A'], ['Dental Base Plan', '$175.56 used of $2,000.00\n$1,824.44 remains', 'N/A'], ['Benefit Maximum - Lifetime', 'Individual', 'Family'], ['Orthodontics', '$0.00 used of $1,000.00\n$1,000.00 remains', 'N/A'], ['Deductibles - Annual', 'Individual', 'Family'], ['Deductible (Applicable to: Basic, Major)', '$0.00 out of $50.00\n$50.00 to go', 'Maximum of $150.00']]
#
#
# ...
