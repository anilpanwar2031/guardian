# %%
import tabula
from tabula import read_pdf

# %%
file_path = 'guardian8.pdf'
dict_list = tabula.read_pdf(file_path, pages='all')
# Out:
# Got stderr: Jun 10, 2023 4:55:35 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 10, 2023 4:55:35 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 10, 2023 4:55:35 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 10, 2023 4:55:35 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 10, 2023 4:55:35 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 10, 2023 4:55:35 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 10, 2023 4:55:35 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 10, 2023 4:55:36 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 10, 2023 4:55:36 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 10, 2023 4:55:36 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 10, 2023 4:55:36 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 10, 2023 4:55:36 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 10, 2023 4:55:36 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 10, 2023 4:55:36 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 10, 2023 4:55:36 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 10, 2023 4:55:36 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 10, 2023 4:55:36 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn
# Jun 10, 2023 4:55:36 PM org.apache.pdfbox.pdmodel.font.PDSimpleFont readEncoding
# WARNING: Unknown encoding: BuiltIn

# %%
print(len(dict_list))
dict_list
# Out:
# 2
# [      Claim Number: 36343F13200 Unnamed: 0  \
#  0   Patient Name: EDMUND GROVER        NaN
#  1  Planholder: VARO MONEY, INC.        NaN
#  2                Line Submitted  Alt Tooth
#  3     No. ADA Codes/Description   Code No.
#  4        1 D2392/Pst Composite2          T
#  5            2 D7140/Extraction          S
#  6        3 D1510/Space Maintain         LR
#  7         4 D9230/Analgesia/N20         FM
#  8                           NaN        NaN
#
#            Patient Account No.:120262917         Plan Number:00558774
#  0        Employee Name: GEOFFREY GROVER            Relationship: SON
#  1                                   NaN                          NaN
#  2  Date of Submitted Considered Covered  Deductible Coverage Benefit
#  3          Service Charge Charge Charge        Amount Percent Amount
#  4         05/09/23 152.00 100.00 100.00              50.00 90% 45.00
#  5           05/09/23 119.00 69.00 69.00                    90% 62.10
#  6         05/09/23 228.00 149.00 149.00                   90% 134.10
#  7             05/09/23 30.00 29.00 0.00                     90% 0.00
#  8           TOTALS 529.00 347.00 318.00           50.00 26.80 241.20  ,
#         Claim Number: 36347F13200 Unnamed: 0 Unnamed: 1  \
#  0     Patient Name: ANDREW CASEY        NaN        NaN
#  1   Planholder: GOENGINEER, INC.        NaN        NaN
#  2                 Line Submitted        Alt      Tooth
#  3      No. ADA Codes/Description       Code        No.
#  4          1 D0120/Periodic Eval        NaN         FM
#  5         2 D0240/Occlusal Image        NaN         FM
#  6         3 D0240/Occlusal Image        NaN         FM
#  7         4 D1120/Child Cleaning        NaN         FM
#  8          5 D1206/Fluoride Varn        NaN         FM
#  9           6 D0274/Bitewing - 4        NaN         FM
#  10                           NaN        NaN        NaN
#
#             Patient Account No.:120320346         Plan Number:00581682
#  0            Employee Name: ANDREW CASEY            Relationship: SON
#  1                                    NaN                          NaN
#  2   Date of Submitted Considered Covered  Deductible Coverage Benefit
#  3           Service Charge Charge Charge        Amount Percent Amount
#  4             05/10/23 39.00 27.00 27.00                   100% 27.00
#  5             05/10/23 27.00 14.00 14.00                   100% 14.00
#  6             05/10/23 27.00 14.00 14.00                   100% 14.00
#  7             05/10/23 52.00 39.00 39.00                   100% 39.00
#  8             05/10/23 36.00 16.00 16.00                   100% 16.00
#  9              05/10/23 52.00 30.00 0.00                    100% 0.00
#  10           TOTALS 233.00 140.00 110.00                  0.00 110.00  ]

# %%
lst = []
for ind, tab in enumerate(dict_list):
    if any('Patient Name' in col for col in tab.columns):
        new_columns_name = {}
        for i in range(len(tab.columns)):
            old_name = tab.columns[i]
            new_name = f'columns{i + 1}'
            new_columns_name[old_name] = new_name
            tab = tab.rename(columns=new_columns_name)
        lst.append(tab.to_dict('records'))
    if len(lst) == 0:
        if any('Claim Number' in col for col in tab.columns):
            new_columns_name = {}
            for i in range(len(tab.columns)):
                old_name = tab.columns[i]
                new_name = f'columns{i + 1}'
                new_columns_name[old_name] = new_name
                tab = tab.rename(columns=new_columns_name)
            lst.append(tab.to_dict('records'))     
lst
# Out:
# [[{'columns1': 'Patient Name: EDMUND GROVER',
#    'columns2': nan,
#    'columns3': 'Employee Name: GEOFFREY GROVER',
#    'columns4': 'Relationship: SON'},
#   {'columns1': 'Planholder: VARO MONEY, INC.',
#    'columns2': nan,
#    'columns3': nan,
#    'columns4': nan},
#   {'columns1': 'Line Submitted',
#    'columns2': 'Alt Tooth',
#    'columns3': 'Date of Submitted Considered Covered',
#    'columns4': 'Deductible Coverage Benefit'},
#   {'columns1': 'No. ADA Codes/Description',
#    'columns2': 'Code No.',
#    'columns3': 'Service Charge Charge Charge',
#    'columns4': 'Amount Percent Amount'},
#   {'columns1': '1 D2392/Pst Composite2',
#    'columns2': 'T',
#    'columns3': '05/09/23 152.00 100.00 100.00',
#    'columns4': '50.00 90% 45.00'},
#   {'columns1': '2 D7140/Extraction',
#    'columns2': 'S',
#    'columns3': '05/09/23 119.00 69.00 69.00',
#    'columns4': '90% 62.10'},
#   {'columns1': '3 D1510/Space Maintain',
#    'columns2': 'LR',
#    'columns3': '05/09/23 228.00 149.00 149.00',
#    'columns4': '90% 134.10'},
#   {'columns1': '4 D9230/Analgesia/N20',
#    'columns2': 'FM',
#    'columns3': '05/09/23 30.00 29.00 0.00',
#    'columns4': '90% 0.00'},
#   {'columns1': nan,
#    'columns2': nan,
#    'columns3': 'TOTALS 529.00 347.00 318.00',
#    'columns4': '50.00 26.80 241.20'}]]

# %%
temp_lst = []
for i in range(len(lst)):
    for obj in lst[i]:
        if type(obj.get('columns1')) != float:
            temp_lst.append(obj)

filtered_lst = []
for i in range(len(temp_lst)):
    if not temp_lst[i]['columns1'].startswith('Patient Name') and not temp_lst[i]['columns1'].startswith('Planholder') and not temp_lst[i]['columns1'].startswith('Line Submitted') and not temp_lst[i]['columns1'].startswith('No.'):
        filtered_lst.append(temp_lst[i])
    if not temp_lst[i]['columns1'].startswith('Claim Number') and not temp_lst[i]['columns1'].startswith('Planholder') and not temp_lst[i]['columns1'].startswith('Line Submitted') and not temp_lst[i]['columns1'].startswith('No.'):
        filtered_lst.append(temp_lst[i])    
print("filtered_lst>>>>>>>>>>>>>>>>>",filtered_lst)
filtered_lst
# Out:
# filtered_lst>>>>>>>>>>>>>>>>> [{'columns1': 'Patient Name: EDMUND GROVER', 'columns2': nan, 'columns3': 'Employee Name: GEOFFREY GROVER', 'columns4': 'Relationship: SON'}, {'columns1': '1 D2392/Pst Composite2', 'columns2': 'T', 'columns3': '05/09/23 152.00 100.00 100.00', 'columns4': '50.00 90% 45.00'}, {'columns1': '1 D2392/Pst Composite2', 'columns2': 'T', 'columns3': '05/09/23 152.00 100.00 100.00', 'columns4': '50.00 90% 45.00'}, {'columns1': '2 D7140/Extraction', 'columns2': 'S', 'columns3': '05/09/23 119.00 69.00 69.00', 'columns4': '90% 62.10'}, {'columns1': '2 D7140/Extraction', 'columns2': 'S', 'columns3': '05/09/23 119.00 69.00 69.00', 'columns4': '90% 62.10'}, {'columns1': '3 D1510/Space Maintain', 'columns2': 'LR', 'columns3': '05/09/23 228.00 149.00 149.00', 'columns4': '90% 134.10'}, {'columns1': '3 D1510/Space Maintain', 'columns2': 'LR', 'columns3': '05/09/23 228.00 149.00 149.00', 'columns4': '90% 134.10'}, {'columns1': '4 D9230/Analgesia/N20', 'columns2': 'FM', 'columns3': '05/09/23 30.00 29.00 0.00', 'columns4': '90% 0.00'}, {'columns1': '4 D9230/Analgesia/N20', 'columns2': 'FM', 'columns3': '05/09/23 30.00 29.00 0.00', 'columns4': '90% 0.00'}]
# [{'columns1': 'Patient Name: EDMUND GROVER',
#   'columns2': nan,
#   'columns3': 'Employee Name: GEOFFREY GROVER',
#   'columns4': 'Relationship: SON'},
#  {'columns1': '1 D2392/Pst Composite2',
#   'columns2': 'T',
#   'columns3': '05/09/23 152.00 100.00 100.00',
#   'columns4': '50.00 90% 45.00'},
#  {'columns1': '1 D2392/Pst Composite2',
#   'columns2': 'T',
#   'columns3': '05/09/23 152.00 100.00 100.00',
#   'columns4': '50.00 90% 45.00'},
#  {'columns1': '2 D7140/Extraction',
#   'columns2': 'S',
#   'columns3': '05/09/23 119.00 69.00 69.00',
#   'columns4': '90% 62.10'},
#  {'columns1': '2 D7140/Extraction',
#   'columns2': 'S',
#   'columns3': '05/09/23 119.00 69.00 69.00',
#   'columns4': '90% 62.10'},
#  {'columns1': '3 D1510/Space Maintain',
#   'columns2': 'LR',
#   'columns3': '05/09/23 228.00 149.00 149.00',
#   'columns4': '90% 134.10'},
#  {'columns1': '3 D1510/Space Maintain',
#   'columns2': 'LR',
#   'columns3': '05/09/23 228.00 149.00 149.00',
#   'columns4': '90% 134.10'},
#  {'columns1': '4 D9230/Analgesia/N20',
#   'columns2': 'FM',
#   'columns3': '05/09/23 30.00 29.00 0.00',
#   'columns4': '90% 0.00'},
#  {'columns1': '4 D9230/Analgesia/N20',
#   'columns2': 'FM',
#   'columns3': '05/09/23 30.00 29.00 0.00',
#   'columns4': '90% 0.00'}]

# %%
# def remove_duplicate_dict(data_list):
#     unique_dicts = list(set(map(lambda x: tuple(sorted(x.items())), data_list)))
#     if len(unique_dicts) < len(data_list):
#         return [dict(t) for t in unique_dicts]
#     else:
#         return data_list

# updated_list = remove_duplicate_dict(filtered_lst)


ls = filtered_lst
for f in ls[:]:
    for k in f.keys():
        if 'Patient' in str(f[k]):
            ls.remove(f)

print("filtered lsit", len(ls))

new_lst = []
for obj in ls:
    new_dict = {}
    columns2 = str(obj['columns2']).split()
    columns3 = obj['columns3'].split()
    columns4 = obj['columns4'].split()
    
    
    if 'columns6' in obj:
        columns6 = obj['columns6'].split()
        columns5 = obj['columns5'].split()

        if len(columns6) == 3:
            new_dict.update({'DeductibleAmount': columns6[0],'CoveragePercent': columns6[1],'BenefitAmount': columns6[2]})
        if len(columns6) == 2:
            new_dict.update({'DeductibleAmount': '','CoveragePercent': columns6[0],'BenefitAmount': columns6[1]})

        if len(columns5) == 3:
            new_dict.update({'SubmittedCharge': columns5[0],'ConsideredCharge': columns5[1],'CoveredCharge': columns5[2]})
        if len(columns5) == 2:
            new_dict.update({'ConsideredCharge': columns5[0],'CoveredCharge': columns5[1]})   
        if len(columns5) == 1:
            new_dict.update({'CoveredCharge': columns5[0]})    


        if len(columns4) == 3:
            new_dict.update({'DateOfService': columns4[0],'SubmittedCharge': columns4[1],'ConsideredCharge': columns4[2]})
        if len(columns4) == 2:
            new_dict.update({'DateOfService': columns4[0],'SubmittedCharge': columns4[1]})
        if len(columns4) == 1:
            new_dict.update({'DateOfService': columns4[0]})

        if len(columns3) == 1:
            new_dict.update({'ToothNo': columns3[0]})

        if len(columns2) == 1:
            new_dict.update({'AltCode': ''})   
        new_dict.update({'SubmittedADACodesDescription': obj["columns1"]})   


    elif 'columns5' in obj:
        columns5 = obj['columns5'].split()
        if len(columns5) == 3:
            new_dict.update({'DeductibleAmount': columns5[0],'CoveragePercent': columns5[1],'BenefitAmount': columns5[2]})
        if len(columns5) == 2:
            new_dict.update({'DeductibleAmount': '','CoveragePercent': columns5[0],'BenefitAmount': columns5[1]})
        
        if len(columns4) == 3:
            new_dict.update({'SubmittedCharge': columns4[0],'ConsideredCharge': columns4[1],'CoveredCharge': columns4[2]})
        if len(columns4) == 2:
            new_dict.update({'ConsideredCharge': columns4[0],'CoveredCharge': columns4[1]})   
        if len(columns4) == 1:
            new_dict.update({'CoveredCharge': columns4[0]})
        
        if len(columns3) == 3:
            new_dict.update({'DateOfService': columns3[0],'SubmittedCharge': columns3[1],'ConsideredCharge': columns3[2]})
        if len(columns3) == 2:
            new_dict.update({'DateOfService': columns3[0],'SubmittedCharge': columns3[1]})
        if len(columns3) == 1:
            new_dict.update({'DateOfService': columns3[0]})
        
        if len(columns2) == 2:
            new_dict.update({'ToothNo': columns2[0],'DateOfService': columns2[1]})
        if len(columns2) == 1:
            new_dict.update({'ToothNo': columns2[0]})   
        
        new_dict.update({'SubmittedADACodesDescription': obj["columns1"],'AltCode': ""})
        
        
   
        
        
    elif 'columns4' in obj:
        if len(columns4) == 3:
            new_dict.update({'DeductibleAmount': columns4[0],'CoveragePercent': columns4[1],'BenefitAmount': columns4[2]})
        if len(columns4) == 2:
            new_dict.update({'DeductibleAmount': '','CoveragePercent': columns4[0],'BenefitAmount': columns4[1]})
        
        if len(columns3) == 4:
            new_dict.update({'DateOfService': columns3[0], 'SubmittedCharge': columns3[1],'ConsideredCharge': columns3[2],'CoveredCharge': columns3[3]})
        if len(columns3) == 3:
            new_dict.update({'SubmittedCharge': columns3[0],'ConsideredCharge': columns3[1],'CoveredCharge': columns3[2]})
        if len(columns3) == 2:
            new_dict.update({'ConsideredCharge': columns3[0],'CoveredCharge': columns3[1]})   
        if len(columns3) == 1:
            new_dict.update({'CoveredCharge': columns3[0]})
        
        
        if len(columns2) == 2:
            new_dict.update({'ToothNo': columns2[0],'DateOfService': columns2[1]})
        if len(columns2) == 1:
            new_dict.update({'ToothNo': columns2[0]})   
        
        new_dict.update({'SubmittedADACodesDescription': obj["columns1"],'AltCode': ""})
        
        
        
    
                
    new_lst.append(new_dict)
new_lst
# Out:
# filtered lsit 8
# [{'DeductibleAmount': '50.00',
#   'CoveragePercent': '90%',
#   'BenefitAmount': '45.00',
#   'DateOfService': '05/09/23',
#   'SubmittedCharge': '152.00',
#   'ConsideredCharge': '100.00',
#   'CoveredCharge': '100.00',
#   'ToothNo': 'T',
#   'SubmittedADACodesDescription': '1 D2392/Pst Composite2',
#   'AltCode': ''},
#  {'DeductibleAmount': '50.00',
#   'CoveragePercent': '90%',
#   'BenefitAmount': '45.00',
#   'DateOfService': '05/09/23',
#   'SubmittedCharge': '152.00',
#   'ConsideredCharge': '100.00',
#   'CoveredCharge': '100.00',
#   'ToothNo': 'T',
#   'SubmittedADACodesDescription': '1 D2392/Pst Composite2',
#   'AltCode': ''},
#  {'DeductibleAmount': '',
#   'CoveragePercent': '90%',
#   'BenefitAmount': '62.10',
#   'DateOfService': '05/09/23',
#   'SubmittedCharge': '119.00',
#   'ConsideredCharge': '69.00',
#   'CoveredCharge': '69.00',
#   'ToothNo': 'S',
#   'SubmittedADACodesDescription': '2 D7140/Extraction',
#   'AltCode': ''},
#  {'DeductibleAmount': '',
#   'CoveragePercent': '90%',
#   'BenefitAmount': '62.10',
#   'DateOfService': '05/09/23',
#   'SubmittedCharge': '119.00',
#   'ConsideredCharge': '69.00',
#   'CoveredCharge': '69.00',
#   'ToothNo': 'S',
#   'SubmittedADACodesDescription': '2 D7140/Extraction',
#   'AltCode': ''},
#  {'DeductibleAmount': '',
#   'CoveragePercent': '90%',
#   'BenefitAmount': '134.10',
#   'DateOfService': '05/09/23',
#   'SubmittedCharge': '228.00',
#   'ConsideredCharge': '149.00',
#   'CoveredCharge': '149.00',
#   'ToothNo': 'LR',
#   'SubmittedADACodesDescription': '3 D1510/Space Maintain',
#   'AltCode': ''},
#  {'DeductibleAmount': '',
#   'CoveragePercent': '90%',
#   'BenefitAmount': '134.10',
#   'DateOfService': '05/09/23',
#   'SubmittedCharge': '228.00',
#   'ConsideredCharge': '149.00',
#   'CoveredCharge': '149.00',
#   'ToothNo': 'LR',
#   'SubmittedADACodesDescription': '3 D1510/Space Maintain',
#   'AltCode': ''},
#  {'DeductibleAmount': '',
#   'CoveragePercent': '90%',
#   'BenefitAmount': '0.00',
#   'DateOfService': '05/09/23',
#   'SubmittedCharge': '30.00',
#   'ConsideredCharge': '29.00',
#   'CoveredCharge': '0.00',
#   'ToothNo': 'FM',
#   'SubmittedADACodesDescription': '4 D9230/Analgesia/N20',
#   'AltCode': ''},
#  {'DeductibleAmount': '',
#   'CoveragePercent': '90%',
#   'BenefitAmount': '0.00',
#   'DateOfService': '05/09/23',
#   'SubmittedCharge': '30.00',
#   'ConsideredCharge': '29.00',
#   'CoveredCharge': '0.00',
#   'ToothNo': 'FM',
#   'SubmittedADACodesDescription': '4 D9230/Analgesia/N20',
#   'AltCode': ''}]

# %%
print(len(new_lst))
# Out:
# 8
